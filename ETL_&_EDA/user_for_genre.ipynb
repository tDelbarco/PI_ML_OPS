# %%
import pandas as pd
import numpy as np
import ETL_functions as etf
import ast

# %% [markdown]
# #  usuario que acumula más horas jugadas para el género dado y una lista de la acumulación de horas jugadas por año

# %%
df_sg = pd.read_json(r"../Datasets/steam_games.json/output_steam_games.json" ,lines=True) # archivo steam_games

# %%
df_sg
# Out:
#               publisher                                 genres  \
# 0                  None                                   None
# 1                  None                                   None
# 2                  None                                   None
# 3                  None                                   None
# 4                  None                                   None
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444             None                                   None
#
#                         app_name                     title  \
# 0                           None                      None
# 1                           None                      None
# ...

# %% [markdown]
#     en este dataframe conservare:
# * app_name(nos servira para relacionar)
# * genres(entrada esperada)
# * id (nos servira para relacionar)
# * release_date(nos servira para tomar el año)
#
# podria usar:
# * url  (podria utilizarse para obtener el nombre en caso de que no se encuentre ni app_name ni title ya que al final de la url tiene el nombre de el juego pero solo hay 1 registro donde es necesario hacer esto)
# * title  (podria servir pararemplazar a app_user pero app_user tiene solo 2 nulos que no son duplicados )
# * tags (la utilizo para rellenar algunos valores nulos de genres sacando los items en comun que tienen)

# %%
del df_sg["publisher"]
del df_sg["specs"]
del df_sg["price"]
del df_sg["early_access"]
del df_sg["developer"]
del df_sg["reviews_url"]
del df_sg["title"]

# %%
df_sg
# Out:
#                                        genres                  app_name  \
# 0                                        None                      None
# 1                                        None                      None
# 2                                        None                      None
# 3                                        None                      None
# 4                                        None                      None
# ...                                       ...                       ...
# 120440  [Casual, Indie, Simulation, Strategy]            Colony On Mars
# 120441              [Casual, Indie, Strategy]  LOGistICAL: South Africa
# 120442            [Indie, Racing, Simulation]             Russian Roads
# 120443                        [Casual, Indie]       EXIT 2 - Directions
# 120444                                   None               Maze Run VR
#
#                                                       url release_date  \
# ...

# %% [markdown]
#     transformo las listas a str para poder manejar los nulos y duplicados

# %%
df_sg["genres"] = df_sg["genres"].astype(str)
df_sg["tags"] = df_sg["tags"].astype(str)

# %%
etf.data_review(df_sg)
# Out:
# Total rows:  120445
#
# Total full null rows:  0
#
# Total duplicated rows: 88309
#          Column                                dType  No_Null_%  No_Null_Qty  \
# 0        genres                      [<class 'str'>]     100.00       120445
# 1      app_name  [<class 'NoneType'>, <class 'str'>]      26.68        32133
# 2           url  [<class 'NoneType'>, <class 'str'>]      26.68        32135
# 3  release_date  [<class 'NoneType'>, <class 'str'>]      24.96        30068
# 4          tags                      [<class 'str'>]     100.00       120445
# 5            id                    [<class 'float'>]      26.68        32133
#
#    Null_%  Null_Qty
# 0    0.00         0
# 1   73.32     88312
# 2   73.32     88310
# 3   75.04     90377
# 4    0.00         0
# 5   73.32     88312

# %% [markdown]
#     gracias a esta funcion podemos darnos rapidamente de la cantidad de nulos en cada columna
#     y que las columnas genres y tags que pasamos a str nos dice que no hay nulos por que la cadena  "None" o  "[]" no son considerados nulos

# %% [markdown]
# ##  eliminacion de duplicados

# %% [markdown]
#     cualquier registro duplicado no resulta importante debido a que los datos ya se encuentran en el dataset
#     (en especial en este caso que tenemos muchas columnas que tienen todas la columnas en null)

# %%
df_sg.drop_duplicates(inplace=True)#elimino todos los duplicados dejando solo registros unicos y con ellos una columna llena de valores null que removere en la siguiente instruccion

# %%
df_sg.head(3)
# Out:
#                                                   genres             app_name  \
# 0                                                   None                 None
# 88310  ['Action', 'Casual', 'Indie', 'Simulation', 'S...  Lost Summoner Kitty
# 88311       ['Free to Play', 'Indie', 'RPG', 'Strategy']            Ironbound
#
#                                                      url release_date  \
# 0                                                   None         None
# 88310  http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 88311  http://store.steampowered.com/app/643980/Ironb...   2018-01-04
#
#                                                     tags        id
# 0                                                   None       NaN
# 88310  ['Strategy', 'Action', 'Indie', 'Casual', 'Sim...  761140.0
# 88311  ['Free to Play', 'Strategy', 'Indie', 'RPG', '...  643980.0

# %%
df_sg.drop(0,inplace=True)#borramos la unica columna que no poseia datos que quedaba

# %%
df_sg.head(3)
# Out:
#                                                   genres  \
# 88310  ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 88311       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 88312  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
#
#                       app_name  \
# 88310      Lost Summoner Kitty
# 88311                Ironbound
# 88312  Real Pool 3D - Poolians
#
#                                                      url release_date  \
# 88310  http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 88311  http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 88312  http://store.steampowered.com/app/670290/Real_...   2017-07-24
#
#                                                     tags        id
# 88310  ['Strategy', 'Action', 'Indie', 'Casual', 'Sim...  761140.0
# 88311  ['Free to Play', 'Strategy', 'Indie', 'RPG', '...  643980.0
# 88312  ['Free to Play', 'Simulation', 'Sports', 'Casu...  670290.0

# %%
etf.data_review(df_sg)
# Out:
# Total rows:  32135
#
# Total full null rows:  0
#
# Total duplicated rows: 0
#          Column                                dType  No_Null_%  No_Null_Qty  \
# 0        genres                      [<class 'str'>]     100.00        32135
# 1      app_name  [<class 'str'>, <class 'NoneType'>]      99.99        32133
# 2           url                      [<class 'str'>]     100.00        32135
# 3  release_date  [<class 'str'>, <class 'NoneType'>]      93.57        30068
# 4          tags                      [<class 'str'>]     100.00        32135
# 5            id                    [<class 'float'>]      99.99        32133
#
#    Null_%  Null_Qty
# 0    0.00         0
# 1    0.01         2
# 2    0.00         0
# 3    6.43      2067
# 4    0.00         0
# 5    0.01         2

# %% [markdown]
# ## reemplazo los valores "listas vacias" en genero por los coincidentes en tags

# %% [markdown]
#     reduciendo la listas a un string separado por , para facilitar el procesamiento a partir de split cadaa vez que necesitemos acceder

# %%
df_sg["genres"] = df_sg["genres"].str.strip("[]").str.replace(" '","").str.replace("'","")

df_sg["genres"]
# Out:
# 88310         Action,Casual,Indie,Simulation,Strategy
# 88311                 Free to Play,Indie,RPG,Strategy
# 88312     Casual,Free to Play,Indie,Simulation,Sports
# 88313                         Action,Adventure,Casual
# 88314                                            None
#                              ...
# 120440               Casual,Indie,Simulation,Strategy
# 120441                          Casual,Indie,Strategy
# 120442                        Indie,Racing,Simulation
# 120443                                   Casual,Indie
# 120444                                           None
# Name: genres, Length: 32135, dtype: object

# %% [markdown]
#     la siguiente linea borra los corchetes las comillas y los espacios entre los valores volviendolos un str separado por , que forman parte del string

# %%
df_sg["tags"] = df_sg["tags"].str.strip("[]").str.replace(" '","").str.replace("'","")

df_sg["tags"]
# Out:
# 88310               Strategy,Action,Indie,Casual,Simulation
# 88311     Free to Play,Strategy,Indie,RPG,Card Game,Trad...
# 88312     Free to Play,Simulation,Sports,Casual,Indie,Mu...
# 88313                               Action,Adventure,Casual
# 88314                            Action,Indie,Casual,Sports
#                                 ...
# 120440                     Strategy,Indie,Casual,Simulation
# 120441                                Strategy,Indie,Casual
# 120442                              Indie,Simulation,Racing
# 120443    Indie,Casual,Puzzle,Singleplayer,Atmospheric,R...
# 120444    Early Access,Adventure,Indie,Action,Simulation,VR
# Name: tags, Length: 32135, dtype: object

# %% [markdown]
#     usamos la funcion creada en el archivo ETL_functions para sacar los elementos unicos de estas columnas

# %%
generos = etf.valores_lista(df_sg,"genres") #obtengo todos los valores unicos de genres
tags = etf.valores_lista(df_sg,"tags")      #obtengo todos  los valores unicos de tags
elementos_comunes = list(set(generos) & set(tags)) #obtengo la interseccion entre esos valores

elementos_comunes#esta es la lista de los valores que sabemos que estan en genero que tambien forman parte de tags
# Out:
# ['Sports',
#  'Utilities',
#  'Audio Production',
#  'Software Training',
#  'Strategy',
#  'Action',
#  'Adventure',
#  'Casual',
#  'Web Publishing',
#  'Early Access',
#  'Free to Play',
#  'Simulation',
#  'Video Production',
#  'Indie',
#  'Photo Editing',
#  'Massively Multiplayer',
#  'Education',
#  'Racing',
#  'None',
#  'RPG']

# %% [markdown]
#     estos son los valores que comparten tanto generos como tags podemos notar que se encuentra el valor None(lo borraremos) y algunos valores que podrian no considerarse generos pero los dejaremos ya que podria ser que dentro de laa plataforma si se consideren como generos

# %%
elementos_comunes.remove('None')# removemos None de esta lista de elementos en comun

# %%
elementos_comunes
# Out:
# ['Sports',
#  'Utilities',
#  'Audio Production',
#  'Software Training',
#  'Strategy',
#  'Action',
#  'Adventure',
#  'Casual',
#  'Web Publishing',
#  'Early Access',
#  'Free to Play',
#  'Simulation',
#  'Video Production',
#  'Indie',
#  'Photo Editing',
#  'Massively Multiplayer',
#  'Education',
#  'Racing',
#  'RPG']

# %% [markdown]
# ### antes de rellenar genres

# %%
df_sg["genres"]
# Out:
# 88310         Action,Casual,Indie,Simulation,Strategy
# 88311                 Free to Play,Indie,RPG,Strategy
# 88312     Casual,Free to Play,Indie,Simulation,Sports
# 88313                         Action,Adventure,Casual
# 88314                                            None
#                              ...
# 120440               Casual,Indie,Simulation,Strategy
# 120441                          Casual,Indie,Strategy
# 120442                        Indie,Racing,Simulation
# 120443                                   Casual,Indie
# 120444                                           None
# Name: genres, Length: 32135, dtype: object

# %%
etf.rellenar_comunes(df_sg,"genres",df_sg,"tags",elementos_comunes)
# Out:
# 'fin de ejecucion'

# %% [markdown]
# ### despues de rellenar genres

# %%
df_sg["genres"]
# Out:
# 88310            Action,Casual,Indie,Simulation,Strategy
# 88311                    Free to Play,Indie,RPG,Strategy
# 88312        Casual,Free to Play,Indie,Simulation,Sports
# 88313                            Action,Adventure,Casual
# 88314                         Sports,Indie,Casual,Action
#                                ...
# 120440                  Casual,Indie,Simulation,Strategy
# 120441                             Casual,Indie,Strategy
# 120442                           Indie,Racing,Simulation
# 120443                                      Casual,Indie
# 120444    Action,Simulation,Adventure,Indie,Early Access
# Name: genres, Length: 32135, dtype: object

# %% [markdown]
#     ahora podemos borrar la columna tags ya que el unico motivo por el que la conservaba era para rellenar genres

# %%
del df_sg["tags"]

# %%
etf.data_review(df_sg)
# Out:
# Total rows:  32135
#
# Total full null rows:  0
#
# Total duplicated rows: 0
#          Column                                dType  No_Null_%  No_Null_Qty  \
# 0        genres                      [<class 'str'>]     100.00        32135
# 1      app_name  [<class 'str'>, <class 'NoneType'>]      99.99        32133
# 2           url                      [<class 'str'>]     100.00        32135
# 3  release_date  [<class 'str'>, <class 'NoneType'>]      93.57        30068
# 4            id                    [<class 'float'>]      99.99        32133
#
#    Null_%  Null_Qty
# 0    0.00         0
# 1    0.01         2
# 2    0.00         0
# 3    6.43      2067
# 4    0.01         2

# %% [markdown]
#     ya contamos con 0 nulls en genres

# %% [markdown]
#     borro los unicos 2 registros que no tiene valor en app_name por que aunque se podrian remplazar procesando url no lo har por el momento

# %%
copia = df_sg.copy()

# %%
df_sg = copia

# %%
df_sg.dropna(inplace=True)

# %%
df_sg
# Out:
#                                              genres                  app_name  \
# 88310       Action,Casual,Indie,Simulation,Strategy       Lost Summoner Kitty
# 88311               Free to Play,Indie,RPG,Strategy                 Ironbound
# 88312   Casual,Free to Play,Indie,Simulation,Sports   Real Pool 3D - Poolians
# 88313                       Action,Adventure,Casual                   弹炸人2222
# 88315                   Action,Adventure,Simulation     Battle Royale Trainer
# ...                                             ...                       ...
# 120439                Action,Adventure,Casual,Indie              Kebab it Up!
# 120440             Casual,Indie,Simulation,Strategy            Colony On Mars
# 120441                        Casual,Indie,Strategy  LOGistICAL: South Africa
# 120442                      Indie,Racing,Simulation             Russian Roads
# 120443                                 Casual,Indie       EXIT 2 - Directions
#
# ...

# %% [markdown]
#     aca decidi borrar todos los nulos que quedaban por que no se el motivo pero no podia tratarlos individualmente probe de muchas maneras (me decia que estaban pero al usar df_sg["app_name"].isna() como filtro tampoco lo traia y al volverlo string y buscar donde sea == "None"cosa que me habia funcionado en un primer etl al que tuve que renunciar debido a problemas entre los merge y tardaban mucho )

# %%
etf.data_review(df_sg)
# Out:
# Total rows:  30066
#
# Total full null rows:  0
#
# Total duplicated rows: 0
#          Column              dType  No_Null_%  No_Null_Qty  Null_%  Null_Qty
# 0        genres    [<class 'str'>]      100.0        30066     0.0         0
# 1      app_name    [<class 'str'>]      100.0        30066     0.0         0
# 2           url    [<class 'str'>]      100.0        30066     0.0         0
# 3  release_date    [<class 'str'>]      100.0        30066     0.0         0
# 4            id  [<class 'float'>]      100.0        30066     0.0         0

# %% [markdown]
# <hr>

# %%
df_ufg_2 = pd.read_parquet(r"../app/users_items.parquet")
df_ufg_3 = pd.read_parquet(r"../app/uitems.parquet")

# %%
df_ufg_2
# Out:
#                        user_id  items_count           steam_id  \
# 0            76561197970982479          277  76561197970982479
# 1                      js41637          888  76561198035864385
# 2                    evcentric          137  76561198007712555
# 3                   Riot-Punch          328  76561197963445855
# 4                        doctr          541  76561198002099482
# ...                        ...          ...                ...
# 88305        76561198323066619           22  76561198323066619
# 88306        76561198326700687          177  76561198326700687
# 88307  XxLaughingJackClown77xX            0  76561198328759259
# 88308        76561198329548331            7  76561198329548331
# 88309        edward_tremethick            0  76561198331598578
#
#                                                 user_url  indice_ui
# 0      http://steamcommunity.com/profiles/76561197970...        0.0
# 1                   http://steamcommunity.com/id/js41637        1.0
# ...

# %% [markdown]
#     de este archivo necesitamos:
# * indice_ui =  columna por la cual relacionamos a otro archivo
# * user_id,steaam_id,user_url(pueden servirnos para relacionar)
#
# y borraremos items count despues de borrar los registros con items counts == 0  ya que estos al no tener juegos en su biblioteca no tendrian que tener horas jugadas

# %%
df_ufg_3
# Out:
#                                                    items  indice_ui
# 0      [{'item_id': '10', 'item_name': 'Counter-Strik...        0.0
# 1      [{'item_id': '10', 'item_name': 'Counter-Strik...        1.0
# 2      [{'item_id': '1200', 'item_name': 'Red Orchest...        2.0
# 3      [{'item_id': '10', 'item_name': 'Counter-Strik...        3.0
# 4      [{'item_id': '300', 'item_name': 'Day of Defea...        4.0
# ...                                                  ...        ...
# 88305  [{'item_id': '413850', 'item_name': 'CS:GO Pla...    88305.0
# 88306  [{'item_id': '11020', 'item_name': 'TrackMania...    88306.0
# 88307                                                 []    88307.0
# 88308  [{'item_id': '304930', 'item_name': 'Unturned'...    88308.0
# 88309                                                 []    88309.0
#
# [88310 rows x 2 columns]

# %% [markdown]
# en este archivo tendremos que trabajar con:
# * indice_ui
# * desanidar items

# %%
merge = df_ufg_2.merge(df_ufg_3,how="inner",on="indice_ui")

# %%
merge

# %% [markdown]
#     borro todos los registros que tienen item count = 0 ya que en teoria si no tienene juegos no tienen horas jugadas

# %%
merge = merge.loc[merge['items_count'] != 0]

# %% [markdown]
#     dataframe sin items count = 0

# %%
merge
